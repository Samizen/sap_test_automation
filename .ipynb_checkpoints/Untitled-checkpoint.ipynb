# %%
import os
from openpyxl import load_workbook
import pandas as pd

# %%
file_path = os.path.join("excel_name_change/excel_files/", "GPO-001 - Goods Purchase - CIF Catalog - Low Dollar.xlsx")

# %%
wb = load_workbook(file_path)

# %%
for sheet in wb.sheetnames:
    sheet_name=sheet
    ws = wb[sheet]
    df = pd.DataFrame(ws.values)
    df = read_through_df(df)
# Out:
# Changing Team to __completed__
# Changing Team to __completed__
# Changing Team to __completed__
# Changing Team to __completed__
# Changing Team to __completed__

# %%
ws=wb['Steps']
ws
# Out:
# <Worksheet "Steps">

# %%
df = pd.DataFrame(ws.values)
df.head()
# Out:
#                 0             1           2            3      4   \
# 0  Scenario Number          None        Step         None   Team
# 1             None          None        None         None   None
# 2             None  Scenario No.        None      Section   None
# 3           BL_001       GPO-001  =ROW(A4)-3  Environment  Buyer
# 4             None          None  =ROW(A5)-3      Catalog  Buyer
#
#                                                   5      6   \
# 0                                       Description   Tcode
# 1                                               None   None
# 2                                               None   None
# 3  Complete script GEN-001 to log into Guided Buy...   None
# 4  Enter search term In the box containing the me...   None
#
#                            7   \
# 0  Test Data / Test Execution
# 1                        None
# 2                        None
# 3             Login\nPassword
# 4                   "goggles"
#
# ...

# %%
df=df.replace('Scenario Number',"test")

# %%
for row_index, row in enumerate(df.values, start=1):
    for col_index, value in enumerate(row, start=1):
        ws.cell(row=row_index, column=col_index, value=value)

# %%
ws=wb['Steps']
df = pd.DataFrame(ws.values)
df.head()
# Out:
#        0             1           2            3      4   \
# 0    test          None        Step         None   Team
# 1    None          None        None         None   None
# 2    None  Scenario No.        None      Section   None
# 3  BL_001       GPO-001  =ROW(A4)-3  Environment  Buyer
# 4    None          None  =ROW(A5)-3      Catalog  Buyer
#
#                                                   5      6   \
# 0                                       Description   Tcode
# 1                                               None   None
# 2                                               None   None
# 3  Complete script GEN-001 to log into Guided Buy...   None
# 4  Enter search term In the box containing the me...   None
#
#                            7   \
# 0  Test Data / Test Execution
# 1                        None
# 2                        None
# 3             Login\nPassword
# 4                   "goggles"
#
#                                                   8   \
# ...

# %%
vars_to_change = {
    "Team":"__completed__",
}
def read_through_df(df:pd.DataFrame):
    for var in vars_to_change:
        print(f"Changing {var} to {vars_to_change[var]}")
        df.replace(var, "test", inplace=True)
    return df

# %%
# Write the modified DataFrame back to the sheet
for row_index, row in enumerate(df.values, start=1):
    for col_index, value in enumerate(row, start=1):
        ws.cell(row=row_index, column=col_index, value=value)

# %%
wb

# %%
for row in ws.iter_rows(min_row=1, max_row=15, values_only=True):
    print(row)
# Out:
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# ('Count of Status', None, 'Status', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# ('Scenario Number', 'Team', '(blank)', '10 - Not Started', '20 - In-Process', '30 - TPR Hold', '40 - DEV Hold', '50 - Pass', '60 - N/A', 'Grand Total', None, None, None, None, None, None, None, None)
# ('PP_018', 'RTR', None, 1, None, None, None, None, None, 1, None, None, None, None, None, None, None, None)
# (None, 'PTP', None, 1, None, None, None, 8, 2, 11, None, None, None, None, None, None, None, None)
# (None, 'PP', None, None, None, None, None, 25, None, 25, None, None, None, None, None, None, None, None)
# (None, 'IMWM', None, None, None, None, None, 5, 4, 9, None, None, None, None, None, None, None, None)
# ...

# %%
a=pd.DataFrame(
    {"a":["apple"],
    "b":["banana"]}
)
